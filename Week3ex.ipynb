# %%
## ***************  EXCERCISE CHAPTER 1 - 2  **************************  ##

# %%
import sys
import nsfg
import thinkstats2
import numpy as np

# %%
def ReadFemResp(dct_file='2002FemResp.dct',
                dat_file='2002FemResp.dat.gz',
                nrows=None):
    """Reads the NSFG respondent data.

    dct_file: string file name
    dat_file: string file name

    returns: DataFrame
    """
    dct = thinkstats2.ReadStataDct(dct_file)
    df = dct.ReadFixedWidth(dat_file, compression='gzip', nrows=nrows)
    CleanFemResp(df)
    return df

# %%
def CleanFemResp(df):
    """Recodes variables from the respondent frame.

    df: DataFrame
    """
    pass

# %%
resp = nsfg.ReadFemResp()
resp.head()
# Out:
#    caseid  rscrinf  rdormres  rostscrn  rscreenhisp  rscreenrace  age_a  \
# 0    2298        1         5         5            1          5.0     27
# 1    5012        1         5         1            5          5.0     42
# 2   11586        1         5         1            5          5.0     43
# 3    6794        5         5         4            1          5.0     15
# 4     616        1         5         4            1          5.0     20
#
#    age_r  cmbirth  agescrn  ...  pubassis_i      basewgt  adj_mod_basewgt  \
# 0     27      902       27  ...           0  3247.916977      5123.759559
# 1     42      718       42  ...           0  2335.279149      2846.799490
# 2     43      708       43  ...           0  2335.279149      2846.799490
# 3     15     1042       15  ...           0  3783.152221      5071.464231
# 4     20      991       20  ...           0  5341.329968      6437.335772
#
#       finalwgt  secu_r  sest  cmintvw  cmlstyr  screentime   intvlngth
# 0  5556.717241       2    18     1234     1222    18:26:36  110.492667
# 1  4744.191350       2    18     1233     1221    16:30:59   64.294000
# 2  4744.191350       2    18     1234     1222    18:19:09   75.149167
# 3  5923.977368       2    18     1234     1222    15:54:43   28.642833
# 4  7229.128072       2    18     1233     1221    14:19:44   69.502667
#
# [5 rows x 3087 columns]

# %%
resp.pregnum.value_counts()
# Out:
# pregnum
# 0     2610
# 2     1432
# 1     1267
# 3     1110
# 4      611
# 5      305
# 6      150
# 7       80
# 8       40
# 9       21
# 10       9
# 11       3
# 12       2
# 14       2
# 19       1
# Name: count, dtype: int64

# %%
## ******************   EXCERCISE FROM CHAPTER 2  ***************************  ##

# %%
#  2-1
# Based on the results in chapter 2 , the difference of mean pragnency length between first babies and other babies is just 0.078 ( 13 hours ).
# The difference is quite small to come to a conclusion that the first borns arrives late.

# %%
# 2-4 Using the variable totalwgt_lb, investigate whether first babies are lighter or heavier than others

#  Load live births
livebirths = preg[preg.outcome == 1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 4
#       1 # 2-4 Using the variable totalwgt_lb, investigate whether first babies are lighter or heavier than others
#       2
#       3 #  Load live births
# ----> 4 livebirths = preg[preg.outcome == 1]
#
# NameError: name 'preg' is not defined
